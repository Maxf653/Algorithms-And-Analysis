# %%
# (Max)heapify
# Max Finkielstein, CS315, DR.Kruse, 9/15/2025 in class activity

# %%
# maxheapify
def max_heapify(A, i, heap_size):
    l = 2 * i + 1
    r = 2 * i + 2
    largest = i

    if l < heap_size and A[l] > A[largest]:
        largest = l
    if r < heap_size and A[r] > A[largest]:
        largest = r

    if largest != i:
        A[i], A[largest] = A[largest], A[i]
        max_heapify(A, largest, heap_size)

# %%
import random

# %%
 n = 15
 A = list(range(n))
random.shuffle(A)

print("Before heapify:", A)
i = 0  # test heapify at root
max_heapify(A, i, len(A))
print("After heapify:", A)
# Out:
# Before heapify: [13, 14, 11, 3, 12, 2, 1, 8, 6, 5, 9, 0, 7, 10, 4]
# After heapify: [14, 13, 11, 3, 12, 2, 1, 8, 6, 5, 9, 0, 7, 10, 4]
